# %%
#Web Scrapping

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math

#Web Source (downloaded dataframe) -> 
#https://public.opendatasoft.com/explore/dataset/georef-united-kingdom-local-authority-district/table/?disjunctive.ctry_code&disjunctive.ctry_name&disjunctive.rgn_code&disjunctive.rgn_name&disjunctive.ctyua_code&disjunctive.ctyua_name&disjunctive.lad_code&disjunctive.lad_name

dfWeb = pd.read_excel("georef-united-kingdom-local-authority-district.xls", header=0)
dfWeb
# Out:
#                            Geo Point  \
# 0       51.9591036348, -0.1925185101
# 1       51.710379369, 0.768584603274
# 2      50.7223009457, -3.51083767703
# 3     51.7669206509, -0.194118408017
# 4       51.7088865574, 0.14873518694
# ..                               ...
# 374  52.9733072749, -0.0377615823488
# 375    52.9125495667, -1.46834672441
# 376    52.5011357822, -1.47587159781
# 377     54.962735313, -1.44445599987
# 378    55.9865111417, -4.51669125546
#
#                                              Geo Shape  Year  \
# 0    {"coordinates": [[[-0.16220526836591, 51.92033...  2020
# 1    {"coordinates": [[[[0.593338760082194, 51.7554...  2020
# 2    {"coordinates": [[[[-3.460874009333644, 50.695...  2020
# 3    {"coordinates": [[[-0.163517920234838, 51.6881...  2020
# 4    {"coordinates": [[[0.021792768117238, 51.62883...  2020
# ..                                                 ...   ...
# 374  {"coordinates": [[[[-0.246714073639072, 52.928...  2020
# ...

# %%
#Creating Dataframe with desired features from the dataframe obtained from the web 
df2=pd.DataFrame()
df2['local_authority_district']=dfWeb['Official Name Local authority district']
df2['local_authority_district_region']=dfWeb['Official Name Region']
df2['local_authority_district_country']=dfWeb['Official Name Country']
df2
# Out:
#     local_authority_district local_authority_district_region  \
# 0        North Hertfordshire                 East of England
# 1                     Maldon                 East of England
# 2                     Exeter                      South West
# 3            Welwyn Hatfield                 East of England
# 4              Epping Forest                 East of England
# ..                       ...                             ...
# 374                   Boston                   East Midlands
# 375                    Derby                   East Midlands
# 376    Nuneaton and Bedworth                   West Midlands
# 377           South Tyneside                      North East
# 378      West Dunbartonshire                        Scotland
#
#     local_authority_district_country
# 0                            England
# 1                            England
# 2                            England
# 3                            England
# 4                            England
# ...

# %%
#--------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#Merging Dataframes (to add new features: local_authority_district_region & local_authority_district_country)
df = pd.read_csv("new_df.csv")
df= pd.merge(df,df2)
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        accident_index  accident_year accident_reference  \
# 0       20010141T3012           2001          0141T3012
# 1       20010141T3023           2001          0141T3023
# 2       20010141T3033           2001          0141T3033
# 3       20010141T3046           2001          0141T3046
# 4       20010141T3047           2001          0141T3047
# ...               ...            ...                ...
# 197312       2.00E+12           2001          984052201
# 197313       2.00E+12           2001          984052301
# 197314       2.00E+12           2001          984052501
# 197315       2.00E+12           2001          984053901
# 197316       2.00E+12           2001          984054401
#
# ...

# %%
#No scaling needed as features added are categorical
#Features will not be encoded to produce clear & understandable dataframes to the human eye

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197317 entries, 0 to 197316
# Data columns (total 41 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_index                               197317 non-null  object
#  1   accident_year                                197317 non-null  int64
#  2   accident_reference                           197317 non-null  object
#  3   location_easting_osgr                        197317 non-null  float64
#  4   location_northing_osgr                       197317 non-null  float64
#  5   longitude                                    197317 non-null  float64
#  6   latitude                                     197317 non-null  float64
#  7   police_force                                 197317 non-null  object
#  8   accident_severity                            197317 non-null  int64
# ...

# %%
#-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#Questions & Visualizations

# %%
def plotBarGraph(data, col, rot, title):
    sns.countplot(data=df, x =col)
    plt.xticks(
    rotation=rot, 
    horizontalalignment='right',
    fontsize='medium'  
        )
    plt.title(title)
    plt.show()

# %%
#Question 1: what is the accident frequency per region in the UK?

#Answer 1:
plotBarGraph(df, 'local_authority_district_region', 40, 'Bar Graph for Accident Frequency Per Region')

# %%
#Question 2: what is the accident frequency per country in the UK?

#Answer 2:
plotBarGraph(df, 'local_authority_district_country', 40, 'Bar Graph for Accident Frequency Per Country')

# %%
#----------------------------------------------------------------------------------------------------------------------------

# %%
#Writing new dataframe file to csv
df.to_csv("new_df_milestone2.csv", index=False)
